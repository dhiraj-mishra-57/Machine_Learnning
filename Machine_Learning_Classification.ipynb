# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')

# %%
def plot_decision_boundary(model, X, y):
    x1, x2 = X[:, 0], X[:, 1]
    x1_min, x1_max = x1.min() - 1, x1.max() + 1
    x2_min, x2_max = x2.min() - 1, x2.max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.1),np.arange(x2_min, x2_max, 0.1))

    Z = model.predict(np.c_[xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)

    plt.contourf(xx1, xx2, Z, alpha=0.4)
    plt.scatter(x1, x2, c=y, marker='o', s=25, edgecolor='k');

# %% [markdown]
# ##  For Two features
# We will first generate a dataset suitable for demonstration and applying classification algorithms using built-in function make_classification in scikit-learn.

# %%
from sklearn.datasets import make_classification

X,y = make_classification(n_samples=100, n_features=2,n_redundant=0,n_clusters_per_class=2,n_informative=2,random_state=1)

print(type(X))
print(X.shape)
print(type(y))
print(y.shape)
# Out:
# <class 'numpy.ndarray'>
# (100, 2)
# <class 'numpy.ndarray'>
# (100,)

# %%
plt.scatter(X[:, 0],X[:, 1], marker='o', c=y,s=25, edgecolor='r');

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

LR_clf = LinearRegression().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(LR_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(LR_clf.score(X_test,y_test)))

plot_decision_boundary(LR_clf,X,y)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.858
# Accuracy of Logistic regression classifier on test set: 0.801

# %% [markdown]
# [Decision Tree classifier](https://towardsdatascience.com/decision-trees-in-machine-learning-641b9c4e8052):
#
# - Tree-like model of decisions
# - Also known as CART algorithm
# - Decision making is explicit and can be visualized
# - Sensitive to the training data used. Slight changes in the training can lead to vastly different trees. This is one of the reasons we prefer Random Forest ensemble given below.
# - Can create over-complex trees that over-fit to the training data
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/CART_tree_titanic_survivors.png" width="300" height="350" />
# <p style="text-align: center;"> Decision Tree classifier for Titanic dataset </p>

# %%
from sklearn.tree import DecisionTreeClassifier

DT_clf = DecisionTreeClassifier().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(DT_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(DT_clf.score(X_test,y_test)))

plot_decision_boundary(DT_clf,X,y)
# Out:
# Accuracy of Logistic regression classifier on training set: 1.000
# Accuracy of Logistic regression classifier on test set: 0.920

# %% [markdown]
# k-Nearest Neighbors classifier:
# - Uses k-nearest neighbors from the training data to predict the label
#
# ![](https://www.mathworks.com/matlabcentral/mlc-downloads/downloads/03faee64-e85e-4ea0-a2b4-e5964949e2d1/d99b9a4d-618c-45f0-86d1-388bdf852c1d/images/screenshot.gif)
#
# The default value for k is 5 in scikit-learn implementation.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf = DecisionTreeClassifier().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(knn_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(knn_clf.score(X_test,y_test)))

plot_decision_boundary(knn_clf,X,y)
# Out:
# Accuracy of Logistic regression classifier on training set: 1.000
# Accuracy of Logistic regression classifier on test set: 0.920

# %% [markdown]
# Support Vector Machines (SVM):
# - An extension of linear classification
# - Separates the classes by choosing a hyperplane that maximizes the distance to the nearest data point on either side and hence known as maximum margin classifier.
# - The data points that are closest to the decision boundary on either side are called support vectors.
# - It minimize the classification error and at the same time maximizes the geometric margin

# %%
from sklearn.svm import SVC

svc_clf = SVC().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(svc_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(svc_clf.score(X_test,y_test)))

plot_decision_boundary(svc_clf,X,y)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.973
# Accuracy of Logistic regression classifier on test set: 0.960

# %% [markdown]
# [Random Forest ensemble](https://machinelearningmastery.com/bagging-and-random-forest-ensemble-algorithms-for-machine-learning/):
# - Ensemble of decision tree classifiers which means it combines predictions from multiple decision tree classifiers to give a more accurate prediction than any individual tree.
# - As noted earlier, decision trees are unstable, that is they are sensitive to the changes in training data. For the ensemble, we take bootstrap samples from the training data and built trees on it.
# - Prone to over-fitting, though less prone than individual decision trees.

# %%
from sklearn.ensemble import RandomForestClassifier

RF_clf = SVC().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(RF_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(RF_clf.score(X_test,y_test)))

plot_decision_boundary(RF_clf,X,y)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.973
# Accuracy of Logistic regression classifier on test set: 0.960

# %% [markdown]
# ##  For Three features

# %%
from sklearn.datasets import make_classification

X1,y1 = make_classification(n_samples=100, n_features=3,n_redundant=0,n_clusters_per_class=2,n_informative=2,random_state=1)

# %%
plt.scatter(X1[:,0],X1[:,1],c=y1,s=25,edgecolors='r');

# %%
plt.scatter(X1[:,0],X1[:,2],c=y1,s=25,edgecolors='r');

# %%
plt.scatter(X1[:,1],X1[:,2],c=y1,s=25,edgecolors='r')

# %% [markdown]
# We will now use `X[:,1] and X[:,2]`

# %%
X1 = X1[:,[1,2]]
X1.shape
# Out:
# (100, 2)

# %%
from sklearn.model_selection import train_test_split

X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

LR_clf1 = LinearRegression().fit(X_train,y_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(LR_clf.score(X_train,y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(LR_clf.score(X_test,y_test)))

plot_decision_boundary(LR_clf1,X1,y1)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.858
# Accuracy of Logistic regression classifier on test set: 0.801

# %%
from sklearn.tree import DecisionTreeClassifier

DT_clf = DecisionTreeClassifier().fit(X1_train,y1_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(DT_clf.score(X1_train,y1_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(DT_clf.score(X1_test,y1_test)))

plot_decision_boundary(DT_clf,X1,y1)
# Out:
# Accuracy of Logistic regression classifier on training set: 1.000
# Accuracy of Logistic regression classifier on test set: 0.520

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_clf = KNeighborsClassifier().fit(X1_train,y1_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(KNN_clf.score(X1_train,y1_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(KNN_clf.score(X1_test,y1_test)))

plot_decision_boundary(KNN_clf,X1,y1)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.573
# Accuracy of Logistic regression classifier on test set: 0.520

# %%
from sklearn.ensemble import RandomForestClassifier

RDN_clf = RandomForestClassifier().fit(X1_train,y1_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(RDN_clf.score(X1_train,y1_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(RDN_clf.score(X1_test,y1_test)))

plot_decision_boundary(RDN_clf,X1,y1)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.947
# Accuracy of Logistic regression classifier on test set: 0.600

# %%
from sklearn.svm import SVC

SVC_clf = SVC().fit(X1_train,y1_train)

print('Accuracy of Logistic regression classifier on training set: {:.3f}'.format(SVC_clf.score(X1_train,y1_train)))
print('Accuracy of Logistic regression classifier on test set: {:.3f}'.format(SVC_clf.score(X1_test,y1_test)))

plot_decision_boundary(SVC_clf,X1,y1)
# Out:
# Accuracy of Logistic regression classifier on training set: 0.600
# Accuracy of Logistic regression classifier on test set: 0.360
